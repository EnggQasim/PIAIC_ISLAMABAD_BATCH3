# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img=mpimg.imread('./1.PNG')
print(img.shape)
plt.imshow(img)
# Out:
# (303, 949, 4)

# %%
from PIL import Image
image = Image.open("./1.PNG")
image.show()

# %%
# pip install opencv-python
import cv2
image = cv2.imread('./1.PNG')
plt.imshow(image)
plt.show()

# %%
import cv2
im = cv2.imread("./qasim.jpeg" )
#im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)  
im.shape
plt.imshow(im)

# %%
from keras.preprocessing import image

X_test=image.load_img('qasim.jpeg',target_size=(28,28),color_mode="rgb"); #loading image and then convert it into grayscale and with it's target size 
X_test=image.img_to_array(X_test); #convert image into array

# %%
X_test.shape
# Out:
# (28, 28, 3)

# %%
plt.imshow(X_test/255)

# %%
import numpy as np
im = np.array(Image.open('qasim.jpeg').convert('L'))
plt.imshow(im)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.imshow(im, cmap=plt.get_cmap('gray'))

# %%
from scipy.io import wavfile
rate1,dat1 = wavfile.read('audio.wav')
print(rate1)
print(dat1)
# Out:
# 8000
# [[ -114    23]
#  [ -241     3]
#  [ -285   -29]
#  ...
#  [ -772 -1059]
#  [ -422  -840]
#  [ -787  -314]]
# /home/muhammadqasim/anaconda3/lib/python3.7/site-packages/scipy/io/wavfile.py:273: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   WavFileWarning)

# %%
import matplotlib.pyplot as plt
import numpy as np
import wave
import sys


spf = wave.open("audio.wav", "r")

# Extract Raw Audio from Wav File
signal = spf.readframes(-1)
signal = np.fromstring(signal, "Int16")




plt.figure(1)
plt.title("Signal Wave...")
plt.plot(signal)
plt.show()
# Out:
# /home/muhammadqasim/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DeprecationWarning: Numeric-style type codes are deprecated and will result in an error in the future.
#   # This is added back by InteractiveShellApp.init_path()
# /home/muhammadqasim/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   # This is added back by InteractiveShellApp.init_path()

# %%
import numpy as np
import cv2

cap = cv2.VideoCapture(0)
 
while(True):
    ret, frame = cap.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
 
    cv2.imshow('frame',gray)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-f0bf06cf872b> in <module>
#       5
#       6 while(True):
# ----> 7     ret, frame = cap.read()
#       8     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#       9
#
# KeyboardInterrupt:

# %%
import cv2

cap = cv2.VideoCapture("mov_bbb.mp4")
ret, frame = cap.read()
while(1):
   ret, frame = cap.read()
   cv2.imshow('frame',frame)
   if cv2.waitKey(2) & 0xFF == ord('q') or ret==False :
       cap.release()
       cv2.destroyAllWindows()
       break
   cv2.imshow('frame',frame)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-1-62a96904087b> in <module>
#       5 while(1):
#       6    ret, frame = cap.read()
# ----> 7    cv2.imshow('frame',frame)
#       8    if cv2.waitKey(2) & 0xFF == ord('q') or ret==False :
#       9        cap.release()
#
# error: OpenCV(4.1.2) /io/opencv/modules/highgui/src/window.cpp:376: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'imshow'

# %%
open??

# %%
open('abc.txt','w')
# Out:
# <_io.TextIOWrapper name='abc.txt' mode='w' encoding='UTF-8'>

# %%
open('abc.txt','x')
# Out:
# <_io.TextIOWrapper name='abc.txt' mode='x' encoding='UTF-8'>

# %%
with open('abc.txt','r+') as fileObj:
    

    fileObj.seek(0)    
    content = fileObj.readlines()
    print(content)
# Out:
# ['\n', 'I love programming5!\n']

# %% [raw]
#                   | r   r+   w   w+   a   a+
# ------------------|--------------------------
# read              | +   +        +        +
# write             |     +    +   +    +   +
# write after seek  |     +    +   +
# create            |          +   +    +   +
# truncate          |          +   +
# position at start | +   +    +   +
# position at end   |                   +   +
