# %% [raw]
# https://www.tutorialspoint.com/python/python_exceptions.htm

# %%
print("line1")
print("line2")
print( 7 / 0)
print("line3")
print("line4")
print("line5")
# Out:
# line1
# line2
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-2-41fe596b8e9b> in <module>
#       1 print("line1")
#       2 print("line2")
# ----> 3 print( 7 / 0)
#       4 print("line3")
#       5 print("line4")
#
# ZeroDivisionError: division by zero

# %%
print(abc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-5a0fe726361e> in <module>
# ----> 1 print(abc)
#
# NameError: name 'abc' is not defined

# %%
a = [2,3]
a[7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-25c60e645f7f> in <module>
#       1 a = [2,3]
# ----> 2 a[7]
#
# IndexError: list index out of range

# %%
d = {"a":2, "b":3}
d['c']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-d3d79bfc3788> in <module>
#       1 d = {"a":2, "b":3}
# ----> 2 d['c']
#
# KeyError: 'c'

# %%
open("abc.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-befa419cc814> in <module>
# ----> 1 open("abc.txt")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'abc.txt'

# %% [markdown]
# # Exception Handling

# %% [raw]
# try:
#     your code
# except (ErrorClass1, ErrClass2,...):
#     if error genreated
# else:
#     if error is not generated
# finally:
#     always Execute

# %%
print("Start")

try:
    print(7 / 0) #
except ZeroDivisionError:
    print("Can't divid any value with zeroZeroDivisionError")
    
print("End")
# Out:
# Start
# Can't divid any value with zeroZeroDivisionError
# End

# %%
print("Start")

try:
    a = [2,30,3]
    print(a[5])
except IndexError:
    print("Can't divid any value with zeroZeroDivisionError")
    
print("End")
# Out:
# Start
# Can't divid any value with zeroZeroDivisionError
# End

# %%
print("Start")

try:
    open("abc.txt")
except FileNotFoundError:
    print("Can't divid any value with zeroZeroDivisionError")
    
print("End")
# Out:
# Start
# Can't divid any value with zeroZeroDivisionError
# End

# %%
try:
    print(7/3)
    a=[2,3]
    print(a[3])
    
    open('abc.txt')
    
except (ZeroDivisionError,FileNotFoundError,IndexError):
    print("we are trying to solve issues")
# Out:
# 2.3333333333333335
# we are trying to solve issues

# %%
try:
    print(7/0)
except ZeroDivisionError:
    print("Can't divided by zero")
    
try:
    a = [2,3]
    print(a[7])
except IndexError:
    print("Out of index")
    
try: 
    open("abc.txt")
except FileNotFoundError: 
    print("File Not Found")
# Out:
# Can't divided by zero
# Out of index
# File Not Found

# %%
try:
    print(7/3)
    a=[2,3]
    print(a[1])
    
    open('abc.txt')
except:
    print("Try to solve some errors")
# Out:
# 2.3333333333333335
# 3
# Try to solve some errors

# %%
try:
    print(7/2)
    a=[2,3]
    print(a[3])
    
    open('abc.txt')
except Exception as e:
    print("Problem:",e)
# Out:
# 3.5
# Problem: list index out of range

# %%
class Student():
    def __init__(self,name, age):
        if True:
            raise Exception("Age Range should be in 18 to 60")
        self.name = name
        self.age = age

s1 = Student('Ali',25)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-23-acd928064600> in <module>
#       6         self.age = age
#       7
# ----> 8 s1 = Student('Ali',25)
#
# <ipython-input-23-acd928064600> in __init__(self, name, age)
#       2     def __init__(self,name, age):
#       3         if True:
# ----> 4             raise Exception("Age Range should be in 18 to 60")
#       5         self.name = name
#       6         self.age = age
#
# Exception: Age Range should be in 18 to 60

# %%
class Student():
    def __init__(self,name, age):
        if age<18 or age>60:
            raise Exception("Age Range should be in 18 to 60")
        self.name = name
        self.age = age

s1 = Student('Ali',75)
s1.age
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-26-ea0207330974> in <module>
#       6         self.age = age
#       7
# ----> 8 s1 = Student('Ali',75)
#       9 s1.age
#
# <ipython-input-26-ea0207330974> in __init__(self, name, age)
#       2     def __init__(self,name, age):
#       3         if age<18 or age>60:
# ----> 4             raise Exception("Age Range should be in 18 to 60")
#       5         self.name = name
#       6         self.age = age
#
# Exception: Age Range should be in 18 to 60

# %%
class Student():
    def __init__(self,name, age):
        if age<18 or age>60:
            raise StudentAgeRangeError("Age Range should be in 18 to 60")
        self.name = name
        self.age = age

class StudentAgeRangeError(Exception):
    pass
        
s1 = Student('Ali',75)
s1.age
# Out:
# ---------------------------------------------------------------------------
# StudentAgeRangeError                      Traceback (most recent call last)
# <ipython-input-27-6e7159376100> in <module>
#       9     pass
#      10
# ---> 11 s1 = Student('Ali',75)
#      12 s1.age
#
# <ipython-input-27-6e7159376100> in __init__(self, name, age)
#       2     def __init__(self,name, age):
#       3         if age<18 or age>60:
# ----> 4             raise StudentAgeRangeError("Age Range should be in 18 to 60")
#       5         self.name = name
#       6         self.age = age
#
# StudentAgeRangeError: Age Range should be in 18 to 60

# %%
try:
    s1 = Student("Hamza", 80)
except  StudentAgeRangeError:
    print("Hello")
# Out:
# Hello
