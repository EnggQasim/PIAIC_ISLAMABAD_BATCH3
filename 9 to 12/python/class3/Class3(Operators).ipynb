# %% [markdown]
# ## Types of Operator
#
# - Arithmetic Operators
# - Comparison (Relational) Operators
# - Assignment Operators
# - Logical Operators
# - Bitwise Operators
# - Membership Operators
# - Identity Operators

# %% [markdown]
# ## Arithmetic Operators

# %% [raw]
# + Addition
# - Subtraction
# * Multiplication
# / Division
# // floor division
# ** power
# % modulus

# %%
5 + 7
# Out:
# 12

# %%
5.0 + 2.7
# Out:
# 7.7

# %%
"Muhammad " + " Qasim"
# Out:
# 'Muhammad  Qasim'

# %%
['1','2'] + ['A',"B"]
# Out:
# ['1', '2', 'A', 'B']

# %%
('1','2') + ('A',"B")
# Out:
# ('1', '2', 'A', 'B')

# %%
{"A":'1',"B":'2'} + {"X":'A',"Z":"B"}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-f71b83533719> in <module>
# ----> 1 {"A":'1',"B":'2'} + {"X":'A',"Z":"B"}
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %%
{"A","B"} + {1,2}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-22e678d4e503> in <module>
# ----> 1 {"A","B"} + {1,2}
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
20 - 2
# Out:
# 18

# %%
25.2 - 2.7
# Out:
# 22.5

# %%
{3,7,8} - {2,3,8}
# Out:
# {7}

# %%
[3,7,8] - [2,3,8]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-834b2a0c3ecc> in <module>
# ----> 1 [3,7,8] - [2,3,8]
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
3 * 2
# Out:
# 6

# %%
"A" * 3
# Out:
# 'AAA'

# %%
["A","B"] * 2
# Out:
# ['A', 'B', 'A', 'B']

# %%
{"A","B"} * 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-5717e9fb2156> in <module>
# ----> 1 {"A","B"} * 2
#
# TypeError: unsupported operand type(s) for *: 'set' and 'int'

# %%
2 ** 3
# Out:
# 8

# %%
12 / 3
# Out:
# 4.0

# %%
12 / 3.0
# Out:
# 4.0

# %%
12.0 / 3
# Out:
# 4.0

# %%
11 / 3
# Out:
# 3.6666666666666665

# %%
11 // 3
# Out:
# 3

# %% [raw]
#         3
#  3  ________
# ___|   11   |___
#        9
#      ______
#         2    # Modulus

# %%
11 % 3
# Out:
# 2

# %%
18 % 5
# Out:
# 3

# %% [markdown]
# # Comparison (Relational) Operators

# %% [raw]
# == equal
# >  grather then
# <  less then
# >= grather then equal
# <= less then equal
# != not equal
# <> not equal

# %%
"Qasim"  ==  "qasim"
# Out:
# False

# %%
'qasim' == "qasim"
# Out:
# True

# %%
2 == 2.0
# Out:
# True

# %%
a = 2
b = 2

a == b
# 2 == 2
# True
# Out:
# True

# %%
2 == '2'
# Out:
# False

# %%
6 > 10
# Out:
# False

# %%
10 > 6
# Out:
# True

# %%
10 > 10
# Out:
# False

# %%
10 >= 10
# Out:
# True

# %%
11 >= 10
# Out:
# True

# %%
10 > 9
# Out:
# True

# %%
"A" > "B"
# Out:
# False

# %%
"B" > "A"
# Out:
# True

# %%
chr(66) > chr(65)
# Out:
# True

# %% [raw]
# 65=A -> 90=Z
# 97=a -> 122=b
# 48=0 -> 57=9

# %%
chr(48)
# Out:
# '0'

# %%
ord("A")
# Out:
# 65

# %%
3 < 6
# Out:
# True

# %%
2 <= 3
# Out:
# True

# %%
'qasim' != "Qasim"
# Out:
# True

# %%
2 != 2
# Out:
# False

# %%
2 <> 2
# Out:
#   File "<ipython-input-58-3be57c68feb7>", line 1
#     2 <> 2
#        ^
# SyntaxError: invalid syntax

# %%
"2" <> "2"
# Out:
#   File "<ipython-input-59-58cd19590351>", line 1
#     "2" <> "2"
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Assignment Operators

# %% [raw]
# =
# +=
# -=
# *=
# **=
# /=
# //=
# %=

# %%
a = 5
print(5)
# Out:
# 5

# %%
a = 5
a = 6
a = 7
a = 8
print(a)
# Out:
# 8

# %%
a = 1
a = a + 2 # 1 + 2 = 3
a = a + 3 # 3 + 3 = 6
a = a + 4 # 6 + 4 = 10
print(a)
# Out:
# 10

# %%
a = 1
a += 2
a += 3
a += 4
print(a)
# Out:
# 10

# %%
a = 100
a -= 2 # 98
a -= 3 # 95
a -= 4 # 91
print(a)
# Out:
# 91

# %%
a = 1
a *= 2 # 2
a *= 3 # 6
a *= 4 # 24
print(a)
# Out:
# 24

# %%
a = 100
a /= 2
a /= 2
print(a)
# Out:
# 25.0

# %%
a = 100
a //= 2
a //= 2
print(a)
# Out:
# 25

# %%
a = 2
a **= 2 # 4 = 2 x 2
a **= 2 # 16 = 4 x 4
print(a)
# Out:
# 16

# %%
a = 2
a **= 3 # 8 = 2 x 2 X 2
a **= 3 # 512 = 8 x 8 x 8
print(a)
# Out:
# 512

# %%
a = 21
a %= 5
print(a)
# Out:
# 1

# %%
a = "A"
a *= 3
print(a)
# Out:
# AAA

# %%
a = "A"
a += "B" # "A" + "B" = "AB"
a += "C" # "AB" + "C" = "ABC"
print(a)
# Out:
# ABC

# %% [markdown]
# # Logical Operators

# %% [raw]
# and = &
# or = |
# not !=, <>

# %%
user = "Qasim"
password = 123

print(user == "Qasim") 
#     "Qasim"=="Qasim" True

print(password==123)
#     123 == 123 # True
# Out:
# True
# True

# %%
True  and True and True and True
# Out:
# True

# %%
True  and True and False and True
# Out:
# False

# %%
True  & True & True & True
# Out:
# True

# %%
True  & True & False & True
# Out:
# False

# %%
a = "A"
b = "B"
c = "C"
d = "D"

print((a=="A") & (b=="B") & (c=="C") & (d=="D"))
#     "A"=="A" & "B"=="B" & "C"=="C" & "D"=="D"
#       True    &    True  &    True   &     True
#                        True


print(a=="A" and b=="B" and c=="C" and d=="D")
# Out:
# True
# True

# %%
True or True or False or True or True
# Out:
# True

# %%
True | True | False | True | True
# Out:
# True

# %%
user = input("User Name")
password = input("Password")

user == "Qasim" or \
user == "Admin" or \
user =="Abc" and \
password=="123"
# Out:
# User NameQasim
# Password333
# True

# %%
user = input("User Name")
password = input("Password")

(user == "Qasim" or user == "Admin" or user =="Abc") \
and password=="123"
# Out:
# User NameQasim
# Password123
# True

# %%
not(True)
# Out:
# False

# %%
not(False)
# Out:
# True

# %%
not (True & True)
# Out:
# False

# %% [markdown]
# # Bitwise Operators

# %% [raw]
# 8,  7,  6,  5,  4,  3,  2,  1, 0
# 2,  2,  2,  2,  2,  2,  2,  2, 2
# =================================
# 256,128,64, 32, 16, 8,  4,   2, 1
#
# 11101 = 29
# 1+4+8+16= 29
# 11100 = 28
#
#
# Example:
#     10011
#
#     Right
#     1          1
#     1          2
#     1          16
#                19

# %% [raw]
# And
#
# 11101 = 29
# 11100 = 28
#
# 11101
# 11100
# ------
# 11100  = 28

# %%
28 & 29
# Out:
# 28

# %%
ord("A") & ord("B")
# Out:
# 64

# %% [raw]
# 10101
# 00101
# _____
# 00101

# %% [raw]
# OR |
#
# 11101 = 29
# 11100 = 28
#
# 11101
# 11100
# ------
# 11101  = 29

# %%
29 | 28
# Out:
# 29

# %% [raw]
# XOR |
#
# 11101 = 29
# 11100 = 28
#
# 11101
# 11100
# ------
# 00001 = 1

# %%
28 ^ 29
# Out:
# 1

# %%
~2
# Out:
# -3

# %%
#11101
29<<2
#1110100
# Out:
# 116

# %%
#11101
29>>2
#00111
# Out:
# 7

# %% [raw]
# # 11001     = 25
# 1100100   = 100
# 00110     = 6

# %%
25<<2
# Out:
# 100

# %%
25>>2
# Out:
# 6

# %% [markdown]
# # Membership Operators

# %%
names = ['Qasim','Hamza','Junaid','Abid']

for name in names:
    if name=='Qasim':
        print(True)
# Out:
# True

# %%
"Qasim" in names
# Out:
# True

# %%
"Ali" not in names
# Out:
# True

# %%
'Pakistan' in "A B C Pakistan"
# Out:
# True

# %% [markdown]
# # Identity Operators

# %%
a = '5'
b = 5
c = a

print(a==b)
print(a==c)
# Out:
# False
# True

# %% [markdown]
# # Control Flow
# - if, else elif

# %% [raw]
# if Logic:
#     code run if logic True
# else:
#     code run if logic False

# %%
if True:
    print("Pakistan")
else:
    print("Zinda bad")
# Out:
# Pakistan

# %%
if False:
    print("Pakistan")
else:
    print("Zinda bad")
# Out:
# Zinda bad

# %%
if True:
    print("Pakistan")
    print("Pakistan")
    print("Pakistan")
    print("Pakistan")
else:
    print("Zinda bad")
# Out:
# Pakistan
# Pakistan
# Pakistan
# Pakistan

# %% [raw]
# True_block if logic else False_block

# %%
"Pakistan" if True else "ZindaBAd"
# Out:
# 'Pakistan'

# %%
"Pakistan" if False else "ZindaBAd"
# Out:
# 'ZindaBAd'
