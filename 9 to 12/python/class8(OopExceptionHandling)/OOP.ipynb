# %% [markdown]
# # Topic
# - Class
# - instance
# - Method
# - Attributes/properties
# - class variable
# - instance variable
# - inheritance
# - encupsolation
# - Abstraction
# - Ploymorphisim

# %% [markdown]
# # Linear Programming

# %%
s1name = "Ali"
s1fname = "Hamza"
s1id = 1
def s1login():pass
def s1logout():pass
def s1quiz_attemp():pass

s2name = "Kashif"
s2fname= "Asif"
s2id = 2
def s2login():pass
def s2logout():pass
def s2quiz_attemp():pass

print(s1fname, s2fname)
# Out:
# Hamza Asif

# %%
# OOP

# %%
class Student():
    def __init__(self, sid):
        self.sid = sid
        self.name = ""
        self.fname = ""
        self.course = ""
        self.fee = 0
        
    def login(self):
        pass
    
    def logout(self):
        pass
    
    def quiz_attemp(self):
        pass
    
    def attendance_mark(self):
        pass
    

        
        

s1 = Student(1)
s2 = Student(2)
s3 = Student(100)

# %%
print(s1.name,s2.name,s3.name, sep="\n")

# %%
s1.name = "Ali"
s3.name = "Hamza"
s2.name = "Konain"

print(s1.name,s2.name,s3.name, sep="\n")
# Out:
# Ali
# Konain
# Hamza

# %%
class Student():
    def __init__(this, sid):
        this.sid = sid
        this.name = ""
        this.fname = ""
        this.course = ""
        this.fee = 0
        
    def login(this):
        pass
    
    def logout(this):
        pass
    
    def quiz_attemp(this):
        pass
    
    def attendance_mark(this):
        pass
        

s1 = Student(1)
s2 = Student(2)
s3 = Student(100)

print(s1.sid, s2.sid, s3.sid, sep="\n")
# Out:
# 1
# 2
# 100

# %%
class Student():
    def __init__(abc, sid):
        abc.sid = sid
        abc.name = ""
        abc.fname = ""
        abc.course = ""
        abc.fee = 0
        
    def login(abc):
        pass
    
    def logout(abc):
        pass
    
    def quiz_attemp(abc):
        pass
    
    def attendance_mark(abc):
        pass
        

s1 = Student(1)
s2 = Student(2)
s3 = Student(100)

print(s1.sid, s2.sid, s3.sid, sep="\n")
# Out:
# 1
# 2
# 100

# %% [markdown]
# # Class Variable

# %%
class Student(): # Class Name
    
    counter = 0 # Class Variable
    
    def __init__(self, sid):
        self.sid = sid # Attributes/properties/field/DataMember
        self.name = ""
        self.fname = ""
        self.course = ""
        self.fee = 0 # Attributes/properties/field/DataMember
        self.user="abc"
        Student.counter += 1
        
    def login(self, user_name, password):#Method/Action/Function
        self.user = user_name
        print("welcome ", self.user)
    
    def logout(self):
        pass
    
    def quiz_attemp(self):
        pass
    
    def attendance_mark(self):
        pass
    

        
        

s1 = Student(1) # counter 1
s2 = Student(2) # counter 2
s3 = Student(100) # counter 3

s1.counter
# Out:
# 3

# %%
Student.counter
# Out:
# 3

# %%
s1.login("Qasim","123")
# Out:
# welcome  Qasim

# %%
s1.DOB = "abcd"
print(s1.DOB)
# Out:
# abcd

# %%
del s1.DOB

# %% [markdown]
# # Inheritance

# %%
class Parent():
    def __init__(self):
        self.name = ""
        self.fname = ""
    
    def speak(self, words=""):
        print(words,"...")
    
    def eat(self, food="roti"):
        print(food)
      

class Child(Parent):
    pass

# %%
p_obj1 = Parent()
p_obj1.name = "ABC"
print(p_obj1.name)
# Out:
# ABC
# ''

# %%
c_obj1 = Child()
c_obj1.speak("Pakistan zinda bad")
# Out:
# Pakistan zinda bad ...

# %%
class Father():
    def __init__(self):
        self.sound = "Fs"
        self.eye_color = "Brown"
        
    def speak(self):
        print("Father Voice")
    
    def listing(self):
        print("FL")
    
class Mother():
    def __init__(self):
        self.face = "Mother"
        self.hair_color = "Black"
        
    def listing(self):
        print("ML")
    
    def abc(self):
        print("MABC")
        
class Child(Father, Mother):
    pass

asif = Child()
asif.listing()
# Out:
# FL

# %% [markdown]
# # Polymorphism

# %% [markdown]
# ### Overloading

# %%
class A():
    
    def abc(self,*n):
        print(sum(n))

obj1 = A()
obj1.abc(1)
obj1.abc(1,3,2,4)
# Out:
# 1
# 10

# %% [markdown]
# # Over Riding

# %%
class A():
    def speak(self):
        print("Speak Function Class A")
        
        
class B(A):
    def speak(self): # Over Riding
        print("Speak Function Class B")
        
obj1 = B()        
obj1.speak()
# Out:
# Speak Function Class B

# %% [markdown]
# # Encopsoluation

# %%
class A():
    def __init__(self, name, age):
        self.__sname = name
        self.__age = age
    
    def display(self):
        print("name:", self.__sname)
        print("Age:",self.__age)
        
        
    def change(self, a, b):
        self.__sname = a
        self.__age = b
        
    def __info(self):
        print("Hello world")
        
    def abc(self):
        self.__info()

obj1 = A("Ali", 25)

# %%
obj1.sname
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-63bb28389f86> in <module>
# ----> 1 obj1.sname
#
# AttributeError: 'A' object has no attribute 'sname'

# %%
obj1.__sname
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-fa8f2de7df4a> in <module>
# ----> 1 obj1.__sname
#
# AttributeError: 'A' object has no attribute '__sname'

# %%
obj1._A__sname
# Out:
# 'Ali'

# %%
obj1.A__sname
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-364f65f80185> in <module>
# ----> 1 obj1.A__sname
#
# AttributeError: 'A' object has no attribute 'A__sname'

# %%
obj1.display()
# Out:
# name: Ali
# Age: 25

# %%
obj1.change("Asif", 30)

obj1.display()
# Out:
# name: Asif
# Age: 30

# %%
obj1.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-3a0370b73e95> in <module>
# ----> 1 obj1.info()
#
# AttributeError: 'A' object has no attribute 'info'

# %%
obj1.abc()
# Out:
# Hellow

# %% [markdown]
# # Abstract Class

# %%
class A: # Abstract class
    def __init__(self, a, b):
        self.a = a
        self.b = b
        
class B(A):
    pass

# %%
obj1 = A(2,5)

# %%
print(obj1.a)
print(obj1.b)
# Out:
# 2
# 5

# %%
obj2 = B(7,9)

# %%
from abc import ABC, abstractmethod

class A(ABC):
    
    def __init__(self, a, b):
        self.a = a
        self.b = b
        
    @abstractmethod
    def abc():
        pass
        
class B(A):
    pass

obj1 = A(5,7)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-b8c886ecbc08> in <module>
#      14     pass
#      15
# ---> 16 obj1 = A(5,7)
#
# TypeError: Can't instantiate abstract class A with abstract methods abc

# %%
obj2 = B(5, 7)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-b894ffb95d50> in <module>
# ----> 1 obj2 = B(5, 7)
#
# TypeError: Can't instantiate abstract class B with abstract methods abc

# %%
from abc import ABC, abstractmethod

class Human(ABC): 
    
    @abstractmethod
    def __init__(self):
        self.name=None
        self.age=None
    
    def display(self,name,age):
        self.name=name
        self.age=age
        return "Objece name is {} {} old.".format(self.name,self.age)

p1=Human()
p1.display('qasim',25)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-d1dbfed76b33> in <module>
#      13         return "Objece name is {} {} old.".format(self.name,self.age)
#      14
# ---> 15 p1=Human()
#      16 p1.display('qasim',25)
#
# TypeError: Can't instantiate abstract class Human with abstract methods __init__

# %%
class Male(Human):
    
    def __init__(self):
        self.name='qasim'
        self.fname='aslam'
    
    def laughter(self):
        return 'Hahahahahah!'

p1=Male()
